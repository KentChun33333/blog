# %% [markdown]
# # MIT-FOX Project
# By Kent Chiu @ 2016 Boston
#
# ## 1. Introduction
# This document might be little messy but it might be the most informative document that providing fully high-level summarization about the corporation project these few years. It is worth to spend some time to read it first if you’d like to take advantages on previous works.
#
# The main objective of this document is to describe what I have done in several sub-projects with a stable version from 2016-0405 to 2016-1215.
# ## 2. Infrastructure
#
# #### Elder computer :
#
# - Win 7
#  - Account-1 : Davis
#  - Pass-1 : bugawoof
#  - Account-2 : Foxconn
#  - Pass-2 : foxconn2015
#
# - Ubuntu :
#  - Account : Root
#  - Pass : 32235
#
# #### Young computer :
# - Win 10 :
#  - Account : Davis
#  - Pass : eager0289

# %% [markdown]
# ## 3. Sub-projects Collections
#
# #### 3.1 Gesture Recognition via Kinect  :
#
# ** 3.1.1 Introdution : **
# - This project is actually from 2011~2016. However, in 2016 this year, I bring a new scenario due to the project requirement. Therefore, I take advantages by carefully looking into the theory detail of this project, which inspires me a lot.
#
# ** 3.1.2 Workable Repository : **
# - Ying’s Project [here](https://github.com/ushadow/handinput)
# - It might be the most useful resource that you could reach on this project.
#
# ** 3.1.3 Infrastructure : **
# - Elder computer, Win7 environmet.
#
# ** 3.1.4 Supporting Documnet from 2015 Foxconn Jerry : **
# - Check with Win7 Desktop, there is a reimplementation document of Ying’s system by Jerry, the document is mainly written by Fox-Jerry, and modified by me. It might be the second useful resource that you could reach on this project.
#
# - In addition, anything about Markov Model related is in this project, if you want to chose this direction as the main target, I would suggest you to read the Ying’s thesis, also google the following Key-words :
#  - Viterbi Algorithm
#  - Hidden Markov Model
#  - Conditional Random Field
#  - Dynamic Time Warp Algorithm
#
# ** 3.1.5 Notice : **
# - The elder computer is really unstable before I arrived MIT due to the fact of due-boot system. It spend me lots of time just to boot it in WIN7 mode. **I would suggest not to build your project on elder computer. **
#
# - The Ubuntu mode is actually builded by 2011~2014, a ancient project done by MIT-FOX members. I am not familiar about this.
#
# #### 3.2 Kinect upgrade and Python wrap :
#
# ** 3.2.1 Introduction : **
# - Kinect 2 provide better resolution and more accurate joint-recognition algorithm in MS-SDK. It is quite nice to use it as the end-device in smart home or samrt conference scenarios.
#
# ** 3.2.2 Dependency : **
# - MS-kinect 2 SDK
# - python2 > 2.7
#
# ** 3.2.3 Infrastructure : **
# - young computer, win10
# - Kinetic 2 SDK is actually not compatible with any WIN version below Win8, and also the open-Ni, open-Kinect is actually not fully support kinetic 2. Therefore, we buy the young computer this year for integration the Kinetic 2.
#
# ** 3.2.4 Workable Script : **
# - C:\Users\Davis\Documents\KentChiu2016\pykinect2TEST.py
#
# ** 3.2.5 Notice : **
# - You have to first connect Kinect 2 to the computer first of course.
# - I build the dependence of the system on young-computer, it should just work or you could open Kinect-SDK system
# - The py-wrap script is help to extract more information from MS-SDK in a pythonic way. If you are comfortable to use visual-studio, you might check other method to extract information.
#
# #### 3.3 Automated Opencv-Cascade CLI suit  (AOC-CLI suit) :
#
# ** 3.3.1 Introduction : **
# - To have an object-detector, you don’t need to build it from scratch, the most common way is to use opencv-cascade trainer & detector. It is the fastest way for building an object-detector. In real production, there are lots of company still rely on  this workflow, due to its convenience & nice performance.
#
# ** 3.3.2 Infrastrue : **
# - Actually in my personal computer MAC-OS-Yosemit, however, by simple midification, it shoud work in young computer.
#
# ** 3.3.3 Dependence : **
# - Python 2 > 2.7 or Python 3 > 3.3
# - Opencv 2.4.11 or 3.1 , notice there are several function is different version of opencv, such as contour and SIFT … etc. In addition, ,
#
# ** 3.3.4 Workable Repository: **
# - [AOC-CLI-suit](https://github.com/KentChun33333/BostonProjects/tree/master/AOC-CLI-suit)
#  - Auto_HAAR_Training.py
#  - Preprocess.py
#
# ** 3.3.5 Notice : **
# - If you want to make my script work in young computer, just make sure
#  - **opencv_traincascade** is callable in your command line interface. In young computer, I install the opencv source at **C:\Users\Davis\opencv.**
#  - Then modify linux-command such cat & mkdir & history to windows style (actually you do not need history function )
#  - You have the right data-input structure described in the script
#  - You execute the script at the right level of the data-input structure.
# - If keep failing, just check the usage-flow of opencv_traincascade, this script is just an automation of it.
#
# #### 3.4 HOG-SVM Object-Detector Suit (HSOD-suit) :
#
# ** 3.4.1 Introduction : **
# - HOG-SVM is nice method for image-recognition and object-detection, therefor, I build an CLI suit on it. This project is actually extendable for a bag-of-features such as LBP, HAAR, HOG… etc. The HMM-DTW method to predict the objects trajectory.
#
# ** 3.4.2 Dependence : **
# - Python
# - Sklearn
# - OpenCV
# - Skimage
#
# ** 3.4.3 Infrastructure **
# - Young computer
#
# ** 3.4.3 Workable Repository: **
# - [HSOD-suit](https://github.com/KentChun33333/BostonProjects/tree/master/HSOD-suit)
#  - common_tool_hub/ (folder to have common_function like src)
#  - conf_hub/ (folder to store your configuration file)
#  - model_hub/ (folder to store your model)
#  - train_agent.py (train your model)
#  - test_agent.py (test your model)
#
#
# ** 3.4.4 Notice : **
# - Just read the README.md  in the project folder :
# - If don’t understand how to configure, google HOG theory might be helpful. The HOG is actually a well-defined, gradient-based, and vote-mechanism-style feature extractor. And the SVM is just a classification algorithm that best suit for binary-classification, there are also multi-class version.
# - The performance of the detector is actually relying on your data-quality and hyper-parameters setting. There are lots hyper-parameters to tune.
# - The sklearn version would have impact on this subproject. If your version is too old or too new, I would suggest you to track the error and modify it to compatible in your version.
#
# #### 3.5 Deep Learning with CNN on image recognition:
#
# ** 3.5.1 Introduction: **
# - Recently [YOLO](https://arxiv.org/pdf/1506.02640v5.pdf) and [SSD](https://arxiv.org/pdf/1512.02325v2.pdf) have been seen as the most state-of-art algorithms on object detection in computer vision. They make a great progress on frame-per-second (FPS) with decent mean-average-perception (mAP).
#
# - One of their main strategy is actually to treat the detection problem as an regression. This ideal seems to be original from [OverFeat](https://arxiv.org/pdf/1312.6229v4.pdf) and be strongly boosted by YOLO. Then SSD is a following work that combine the ideal with region-proposal-network from [FastRCNN](https://arxiv.org/pdf/1504.08083v2.pdf) to make a trade-off on mAP vs FPS.
#
# ** 3.5.2 Dependence : **
# - Tensorflow (in Linux/Unix)
# - Theano (in Windows)
#
# ** 3.5.3 Infrastructure : **
# - Tensorflow (young-computer with docker)
# - Theano (young-computer)
#
# ** 3.5.3 Workable Repo : **
# - Currently I only have lots of expriment-level scripts, and most of experiment scripts are  modifided from this [theano-repo](https://github.com/Theano/Theano/wiki/Related-projects) and this [tensorflow-repo](https://github.com/tensorflow/models), and I actually spend most of time on training it with our own data, fine-tuning the training step, visualizing the training condition … and so on.
#
# ** 3.5.4 Notice :**
# - Basically I used the Alexnet & VGGnet-based network structure a lot.
#
# - The GPU is really unstable on young-computer, so I disable it. You could also consider to switch the system to Ubuntu. It might provide a more stable condition on GPU. However, there will be some trade-offs.
#
# - If you would like to install CUDA in Ubuntu 14.04 LTS, you might check my [Blog Post](https://kentchun33333.github.io/InstallCUDAUbuntu.html#InstallCUDAUbuntu)
#
# ## 4. Summary :
# Depending on capability, wishes, interests, project requirement and … so on, we probably would have different scenarios/problems/raw data to solve. Since it is all about data defining the solution, pick up something above that is useful to you. If it is insufficient, just create new one. This is exactly how I did this year, and I just saw how much the improvement on myself : )
#
#
# Finally , I’d like to thanks Prof. Randall Davis. He is the best teacher and professor I’ve ever meet. He did not limit my research directions and let me try anything, then guide me with lots of helpful suggestions.

# %% [markdown]
# ## 5. Contact Information :
# - Email : kentchun33333@foxmail.com
# - You could find more informatino about me on my [blog](https://kentchun33333.github.io)
